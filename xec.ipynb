# %%
#pip install pandas numpy matplotlib tensorflow scikit-learn pandas_datareader

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Carregar os dados
df = pd.read_csv('C:\\Users\\denis\\Estudos\\Estudos_IBM\\Certificado Profissional Engenharia de IA da IBM\\Introdução à aprendizagem profunda e às redes neurais com o Keras\\Dados Históricos XEC_USD - Binance.csv')

# Converter a coluna de data para datetime
df['Data'] = pd.to_datetime(df['Data'], format='%d.%m.%Y')

# Substituir vírgulas por pontos e converter as colunas para float
for feature in ['Último', 'Máxima', 'Mínima']:
    df[feature] = df[feature].str.replace(',', '.').astype(float)

# Definir as features e preparar os dados
features = ['Último', 'Máxima', 'Mínima']

# Normalizar dados
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df[features])

# Preparar dados para treinamento
def create_sequences(data, time_step=10):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:i + time_step])
        y.append(data[i + time_step])
    return np.array(X), np.array(y)

time_step = 10  # Número de passos no tempo
X, y = create_sequences(scaled_data, time_step)

# Dividir os dados em treinamento e teste
split_index = int(0.8 * len(X))
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Construir o modelo
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(time_step, len(features))),
    LSTM(50),
    Dense(len(features))  # Prever todas as features
])

model.compile(optimizer='adam', loss='mean_squared_error')

# Treinar o modelo
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.1
)

# Avaliar o modelo
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverter a normalização das previsões
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# Calcular métricas de erro
mae_train = mean_absolute_error(scaler.inverse_transform(y_train), train_predict)
mse_train = mean_squared_error(scaler.inverse_transform(y_train), train_predict)
rmse_train = np.sqrt(mse_train)
r2_train = r2_score(scaler.inverse_transform(y_train), train_predict)

mae_test = mean_absolute_error(scaler.inverse_transform(y_test), test_predict)
mse_test = mean_squared_error(scaler.inverse_transform(y_test), test_predict)
rmse_test = np.sqrt(mse_test)
r2_test = r2_score(scaler.inverse_transform(y_test), test_predict)

# Exibir resultados
print(f"MAE (Treinamento): {mae_train}")
print(f"MSE (Treinamento): {mse_train}")
print(f"RMSE (Treinamento): {rmse_train}")
print(f"R² (Treinamento): {r2_train}")

print(f"MAE (Teste): {mae_test}")
print(f"MSE (Teste): {mse_test}")
print(f"RMSE (Teste): {rmse_test}")
print(f"R² (Teste): {r2_test}")

# Prever futuros valores
def predict_future(model, last_data, future_steps, scaler, time_step):
    predictions = []
    data = last_data.copy()
    for _ in range(future_steps):
        pred = model.predict(data[np.newaxis, ...])
        predictions.append(pred[0])
        data = np.vstack([data[1:], pred])
    return np.array(predictions)

# Dados para previsão futura
last_data = scaled_data[-time_step:]
future_steps = 90
future_predictions = predict_future(model, last_data, future_steps, scaler, time_step)

# Inverter a normalização dos dados futuros
future_predictions = scaler.inverse_transform(future_predictions)

# Configurar a exibição de números no formato decimal completo
np.set_printoptions(suppress=True)

# Agora, as previsões futuras serão exibidas sem notação científica
print(f"Previsões futuras para {future_steps} dias:")
print(future_predictions)
# Out:
# C:\Users\denis\anaconda3\envs\IA_env\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 0.0571 - val_loss: 0.0090
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0108 - val_loss: 0.0013
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0059 - val_loss: 0.0013
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0059 - val_loss: 0.0012
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0053 - val_loss: 0.0012
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0042 - val_loss: 0.0013
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0040 - val_loss: 0.0012
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0044 - val_loss: 0.0015
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0037 - val_loss: 0.0010
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0033 - val_loss: 0.0010
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0041 - val_loss: 0.0011
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0032 - val_loss: 0.0016
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0030 - val_loss: 9.3143e-04
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0026 - val_loss: 0.0010
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0026 - val_loss: 9.8646e-04
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - val_loss: 9.5578e-04
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0023 - val_loss: 9.0234e-04
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0023 - val_loss: 0.0015
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0032 - val_loss: 9.1238e-04
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0025 - val_loss: 9.8777e-04
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0024 - val_loss: 8.8642e-04
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0018 - val_loss: 8.2471e-04
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0022 - val_loss: 9.7332e-04
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0025 - val_loss: 8.3569e-04
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0021 - val_loss: 8.7241e-04
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0022 - val_loss: 7.5017e-04
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0016 - val_loss: 7.2606e-04
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0016 - val_loss: 7.3170e-04
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0017 - val_loss: 7.3786e-04
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0018 - val_loss: 7.1305e-04
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0016 - val_loss: 7.4016e-04
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0019 - val_loss: 7.0730e-04
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 6.3090e-04
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0022 - val_loss: 6.5614e-04
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0013 - val_loss: 6.1710e-04
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0019 - val_loss: 5.9709e-04
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013 - val_loss: 6.1397e-04
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0016 - val_loss: 6.7327e-04
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0016 - val_loss: 7.3263e-04
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0016 - val_loss: 5.6219e-04
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0011 - val_loss: 5.5411e-04
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0016 - val_loss: 5.4846e-04
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0015 - val_loss: 6.7316e-04
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0012 - val_loss: 6.6038e-04
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 7.6277e-04
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0017 - val_loss: 6.2243e-04
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0011 - val_loss: 5.3146e-04
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0011 - val_loss: 5.6721e-04
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0012 - val_loss: 5.7023e-04
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0013 - val_loss: 5.2421e-04
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - val_loss: 5.4642e-04
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0011 - val_loss: 5.0588e-04
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0013 - val_loss: 5.0318e-04
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0014 - val_loss: 9.8411e-04
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016 - val_loss: 5.2880e-04
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0010 - val_loss: 4.8317e-04
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0015 - val_loss: 5.1594e-04
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0014 - val_loss: 4.8283e-04
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0012 - val_loss: 4.7666e-04
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0011 - val_loss: 4.5473e-04
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0012 - val_loss: 5.0801e-04
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0012 - val_loss: 4.4883e-04
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.8708e-04 - val_loss: 4.4881e-04
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0013 - val_loss: 5.1288e-04
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 4.7761e-04
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0013 - val_loss: 4.5178e-04
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0012 - val_loss: 5.5531e-04
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0015 - val_loss: 4.8536e-04
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 4.7907e-04
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0017 - val_loss: 6.3622e-04
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - val_loss: 4.8047e-04
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.9105e-04 - val_loss: 4.9132e-04
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0011 - val_loss: 4.6198e-04
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0011 - val_loss: 5.6359e-04
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013 - val_loss: 4.1003e-04
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0011 - val_loss: 4.0268e-04
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 9.4615e-04 - val_loss: 4.3424e-04
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 9.0387e-04 - val_loss: 4.0625e-04
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0010 - val_loss: 4.0088e-04
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0010 - val_loss: 4.3582e-04
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.7854e-04 - val_loss: 3.9373e-04
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.9866e-04 - val_loss: 4.3089e-04
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0011 - val_loss: 4.6792e-04
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0011 - val_loss: 3.8140e-04
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0012 - val_loss: 7.9056e-04
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - val_loss: 4.3425e-04
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0011 - val_loss: 3.9026e-04
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.8904e-04 - val_loss: 3.8719e-04
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 4.1966e-04
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.1225e-04 - val_loss: 3.8689e-04
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0012 - val_loss: 4.5657e-04
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - val_loss: 3.7142e-04
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.7756e-04 - val_loss: 3.6883e-04
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.2167e-04 - val_loss: 3.8151e-04
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.2545e-04 - val_loss: 3.6588e-04
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 4.2030e-04
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 3.9295e-04
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.1922e-04 - val_loss: 3.7496e-04
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# MAE (Treinamento): 1.2227543791187773e-06
# MSE (Treinamento): 4.558633239461317e-12
# RMSE (Treinamento): 2.1350956042906643e-06
# R² (Treinamento): 0.9674467155191161
# MAE (Teste): 1.121366183789176e-06
# MSE (Teste): 2.628646623647605e-12
# RMSE (Teste): 1.621310156523916e-06
# R² (Teste): 0.9330585668100921
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Previsões futuras para 90 dias:
# [[0.00003884 0.00004071 0.00003727]
#  [0.00003868 0.00004063 0.0000371 ]
#  [0.00003853 0.00004051 0.00003694]
#  [0.00003835 0.00004033 0.00003675]
#  [0.00003814 0.00004012 0.00003655]
#  [0.00003792 0.00003989 0.00003632]
#  [0.00003769 0.00003963 0.00003609]
#  [0.00003743 0.00003935 0.00003584]
#  [0.00003718 0.00003908 0.0000356 ]
#  [0.00003693 0.0000388  0.00003535]
#  [0.00003667 0.0000385  0.0000351 ]
#  [0.0000364  0.00003821 0.00003484]
#  [0.00003613 0.00003791 0.00003459]
#  [0.00003586 0.00003761 0.00003434]
#  [0.00003558 0.00003731 0.00003408]
#  [0.00003531 0.00003701 0.00003383]
#  [0.00003504 0.00003671 0.00003358]
#  [0.00003477 0.00003642 0.00003332]
#  [0.0000345  0.00003612 0.00003307]
#  [0.00003423 0.00003583 0.00003282]
#  [0.00003396 0.00003553 0.00003257]
#  [0.00003369 0.00003524 0.00003232]
#  [0.00003343 0.00003495 0.00003207]
#  [0.00003317 0.00003467 0.00003183]
#  [0.00003291 0.00003439 0.00003158]
#  [0.00003265 0.00003411 0.00003134]
#  [0.00003239 0.00003383 0.0000311 ]
#  [0.00003214 0.00003356 0.00003087]
#  [0.00003189 0.00003329 0.00003063]
#  [0.00003165 0.00003302 0.0000304 ]
#  [0.0000314  0.00003276 0.00003018]
#  [0.00003117 0.00003251 0.00002995]
#  [0.00003093 0.00003226 0.00002973]
#  [0.0000307  0.00003201 0.00002952]
#  [0.00003048 0.00003177 0.0000293 ]
#  [0.00003025 0.00003153 0.0000291 ]
#  [0.00003004 0.0000313  0.00002889]
#  [0.00002982 0.00003107 0.00002869]
#  [0.00002962 0.00003085 0.00002849]
#  [0.00002941 0.00003063 0.0000283 ]
#  [0.00002921 0.00003042 0.00002811]
#  [0.00002902 0.00003022 0.00002793]
#  [0.00002883 0.00003002 0.00002775]
#  [0.00002865 0.00002982 0.00002758]
#  [0.00002847 0.00002963 0.00002741]
#  [0.00002829 0.00002945 0.00002724]
#  [0.00002812 0.00002927 0.00002708]
#  [0.00002796 0.00002909 0.00002693]
#  [0.0000278  0.00002893 0.00002678]
#  [0.00002764 0.00002876 0.00002663]
#  [0.00002749 0.0000286  0.00002649]
#  [0.00002735 0.00002845 0.00002635]
#  [0.00002721 0.0000283  0.00002621]
#  [0.00002707 0.00002816 0.00002608]
#  [0.00002694 0.00002802 0.00002596]
#  [0.00002681 0.00002789 0.00002584]
#  [0.00002669 0.00002776 0.00002572]
#  [0.00002657 0.00002763 0.00002561]
#  [0.00002645 0.00002751 0.0000255 ]
#  [0.00002634 0.00002739 0.00002539]
#  [0.00002623 0.00002728 0.00002529]
#  [0.00002613 0.00002717 0.00002519]
#  [0.00002603 0.00002707 0.00002509]
#  [0.00002593 0.00002697 0.000025  ]
#  [0.00002584 0.00002687 0.00002491]
#  [0.00002575 0.00002678 0.00002482]
#  [0.00002566 0.00002669 0.00002474]
#  [0.00002558 0.0000266  0.00002466]
#  [0.00002549 0.00002652 0.00002459]
#  [0.00002542 0.00002644 0.00002451]
#  [0.00002534 0.00002636 0.00002444]
#  [0.00002527 0.00002628 0.00002437]
#  [0.0000252  0.00002621 0.00002431]
#  [0.00002514 0.00002614 0.00002424]
#  [0.00002507 0.00002608 0.00002418]
#  [0.00002501 0.00002601 0.00002412]
#  [0.00002495 0.00002595 0.00002407]
#  [0.00002489 0.0000259  0.00002401]
#  [0.00002484 0.00002584 0.00002396]
#  [0.00002479 0.00002578 0.00002391]
#  [0.00002474 0.00002573 0.00002386]
#  [0.00002469 0.00002568 0.00002382]
#  [0.00002464 0.00002563 0.00002377]
#  [0.0000246  0.00002559 0.00002373]
#  [0.00002456 0.00002554 0.00002369]
#  [0.00002451 0.0000255  0.00002365]
#  [0.00002447 0.00002546 0.00002361]
#  [0.00002444 0.00002542 0.00002357]
#  [0.0000244  0.00002538 0.00002354]
#  [0.00002437 0.00002535 0.00002351]]
